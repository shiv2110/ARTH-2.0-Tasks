# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread("./assets/eren.png")
img2 = cv2.imread("./assets/levi.png")

# %%
print(img1.shape, img2.shape)
# Out:
# (720, 720, 3) (1464, 1464, 3)

# %%
img2 = cv2.resize(img2, (720, 720))

# %%
img2.shape
# Out:
# (720, 720, 3)

# %%
result = np.hstack((img1, img2))

# %%
plt.imshow(result)
plt.axis(False)
# Out:
# (-0.5, 1439.5, 719.5, -0.5)

# %%
cv2.imshow("AOT", result)
cv2.waitKey(0) 
cv2.destroyAllWindows()
